# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 617

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "d7c7657b2c30f8daab2ebd825a8a11f5"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d7c7657b2c30f8daab2ebd825a8a11f5

# %%
# Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Loop through the cities list.
# Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# Build the city_url or endpoint for each city.
# Log the URL and the record and set numbers.
# Make an API request for each city.
# Parse the JSON weather data for the following:
    # City, country, and date
    # Latitude and longitude
    # Maximum temperature
    # Humidity
    # Cloudiness
    # Wind speed
# Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
try:
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    # Parse out the needed data.
    city_lat = city_weather["coord"]["lat"]
    city_lng = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
    city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
    city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Date": city_date})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | vrangel
# Processing Record 3 of Set 1 | deputatskiy
# Processing Record 4 of Set 1 | sao filipe
# Processing Record 5 of Set 1 | san pedro
# Processing Record 6 of Set 1 | faya
# Processing Record 7 of Set 1 | port hardy
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | cumberland
# Processing Record 10 of Set 1 | batemans bay
# Processing Record 11 of Set 1 | carauari
# Processing Record 12 of Set 1 | te anau
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | burica
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | tsihombe
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | chuy
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | thinadhoo
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | belushya guba
# Processing Record 26 of Set 1 | fergus falls
# Processing Record 27 of Set 1 | at-bashi
# Processing Record 28 of Set 1 | kieta
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | basco
# Processing Record 33 of Set 1 | bow island
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | nome
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | alugan
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | praya
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | pisco
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | ekhabi
# Processing Record 48 of Set 1 | the pas
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | touros
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | brae
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | lasa
# Processing Record 7 of Set 2 | sevierville
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | grand river south east
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | belmonte
# Processing Record 12 of Set 2 | taolanaro
# Processing Record 13 of Set 2 | moba
# Processing Record 14 of Set 2 | qafsah
# Processing Record 15 of Set 2 | hit
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | cardinal
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | emerald
# Processing Record 20 of Set 2 | byron bay
# Processing Record 21 of Set 2 | gidole
# Processing Record 22 of Set 2 | nishihara
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | harper
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | vaitupu
# Processing Record 29 of Set 2 | merauke
# Processing Record 30 of Set 2 | san vicente
# Processing Record 31 of Set 2 | bad aibling
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | pontecorvo
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | mount gambier
# Processing Record 37 of Set 2 | ugoofaaru
# Processing Record 38 of Set 2 | santa cruz
# Processing Record 39 of Set 2 | iwanai
# Processing Record 40 of Set 2 | lithgow
# Processing Record 41 of Set 2 | kayes
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | vallenar
# Processing Record 44 of Set 2 | coquimbo
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | coahuayana
# Processing Record 48 of Set 2 | parana
# Processing Record 49 of Set 2 | pryshyb
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | port hedland
# Processing Record 2 of Set 3 | benguela
# Processing Record 3 of Set 3 | port hawkesbury
# Processing Record 4 of Set 3 | santa
# Processing Record 5 of Set 3 | praia da vitoria
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | richards bay
# Processing Record 8 of Set 3 | mailsi
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | crestview
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | guerrero negro
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | green river
# Processing Record 18 of Set 3 | urdzhar
# Processing Record 19 of Set 3 | aksarka
# Processing Record 20 of Set 3 | arrifes
# Processing Record 21 of Set 3 | da nang
# Processing Record 22 of Set 3 | laguna
# Processing Record 23 of Set 3 | pimentel
# Processing Record 24 of Set 3 | otane
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | jinchang
# Processing Record 27 of Set 3 | berlevag
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | de aar
# Processing Record 30 of Set 3 | camocim
# Processing Record 31 of Set 3 | pauini
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | riyadh
# Processing Record 34 of Set 3 | portland
# Processing Record 35 of Set 3 | malatya
# Processing Record 36 of Set 3 | cockburn town
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | torbay
# Processing Record 39 of Set 3 | gurskoye
# Processing Record 40 of Set 3 | monrovia
# Processing Record 41 of Set 3 | shimoda
# Processing Record 42 of Set 3 | xining
# Processing Record 43 of Set 3 | svaty jur
# Processing Record 44 of Set 3 | karratha
# Processing Record 45 of Set 3 | mount isa
# Processing Record 46 of Set 3 | purace
# Processing Record 47 of Set 3 | puerto leguizamo
# Processing Record 48 of Set 3 | maierus
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | dongsheng
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | dunedin
# Processing Record 3 of Set 4 | sarangani
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | hobart
# Processing Record 6 of Set 4 | tabou
# Processing Record 7 of Set 4 | praia
# Processing Record 8 of Set 4 | zambezi
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | kamenka
# Processing Record 11 of Set 4 | belaya gora
# Processing Record 12 of Set 4 | innisfail
# Processing Record 13 of Set 4 | umm kaddadah
# Processing Record 14 of Set 4 | pangnirtung
# Processing Record 15 of Set 4 | odweyne
# Processing Record 16 of Set 4 | karauzyak
# Processing Record 17 of Set 4 | chatham
# Processing Record 18 of Set 4 | livingston
# Processing Record 19 of Set 4 | alice springs
# Processing Record 20 of Set 4 | matamoros
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | souillac
# Processing Record 23 of Set 4 | tilichiki
# Processing Record 24 of Set 4 | hihifo
# Processing Record 25 of Set 4 | cootamundra
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | dingle
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | tairua
# Processing Record 30 of Set 4 | durazno
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | goderich
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | christchurch
# Processing Record 35 of Set 4 | svetlaya
# Processing Record 36 of Set 4 | porto novo
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | luena
# Processing Record 39 of Set 4 | ilulissat
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | itupiranga
# Processing Record 42 of Set 4 | maiduguri
# Processing Record 43 of Set 4 | tucuma
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | henties bay
# Processing Record 47 of Set 4 | mecca
# Processing Record 48 of Set 4 | mugur-aksy
# Processing Record 49 of Set 4 | illoqqortoormiut
# Processing Record 50 of Set 4 | pacific grove
# Processing Record 1 of Set 5 | arlit
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | kazachinskoye
# Processing Record 4 of Set 5 | amboise
# Processing Record 5 of Set 5 | cam ranh
# Processing Record 6 of Set 5 | najran
# Processing Record 7 of Set 5 | filingue
# Processing Record 8 of Set 5 | ostrovnoy
# Processing Record 9 of Set 5 | soars
# Processing Record 10 of Set 5 | bilibino
# Processing Record 11 of Set 5 | saint-esteve
# Processing Record 12 of Set 5 | labutta
# Processing Record 13 of Set 5 | barentsburg
# Processing Record 14 of Set 5 | neiafu
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | the valley
# Processing Record 17 of Set 5 | east london
# Processing Record 18 of Set 5 | smithers
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | juba
# Processing Record 21 of Set 5 | mrirt
# Processing Record 22 of Set 5 | aswan
# Processing Record 23 of Set 5 | ankang
# Processing Record 24 of Set 5 | naryan-mar
# Processing Record 25 of Set 5 | tsumeb
# Processing Record 26 of Set 5 | samalaeulu
# Processing Record 27 of Set 5 | road town
# Processing Record 28 of Set 5 | haimen
# Processing Record 29 of Set 5 | walvis bay
# Processing Record 30 of Set 5 | guatire
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | bud
# Processing Record 33 of Set 5 | port augusta
# Processing Record 34 of Set 5 | vaitape
# Processing Record 35 of Set 5 | tautira
# Processing Record 36 of Set 5 | yumen
# Processing Record 37 of Set 5 | seoul
# Processing Record 38 of Set 5 | madanapalle
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | dharchula
# Processing Record 41 of Set 5 | shenxian
# Processing Record 42 of Set 5 | comodoro rivadavia
# Processing Record 43 of Set 5 | opuwo
# Processing Record 44 of Set 5 | khandyga
# Processing Record 45 of Set 5 | thompson
# Processing Record 46 of Set 5 | hecun
# Processing Record 47 of Set 5 | bilma
# Processing Record 48 of Set 5 | kapoeta
# Processing Record 49 of Set 5 | victor harbor
# Processing Record 50 of Set 5 | mutsamudu
# Processing Record 1 of Set 6 | sorland
# Processing Record 2 of Set 6 | lorengau
# Processing Record 3 of Set 6 | ranong
# Processing Record 4 of Set 6 | attawapiskat
# Processing Record 5 of Set 6 | atasu
# Processing Record 6 of Set 6 | ketchikan
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | shchigry
# Processing Record 9 of Set 6 | poum
# Processing Record 10 of Set 6 | dondo
# Processing Record 11 of Set 6 | show low
# Processing Record 12 of Set 6 | millinocket
# Processing Record 13 of Set 6 | marawi
# Processing Record 14 of Set 6 | fairbanks
# Processing Record 15 of Set 6 | pevek
# Processing Record 16 of Set 6 | kloulklubed
# Processing Record 17 of Set 6 | gat
# Processing Record 18 of Set 6 | kaitangata
# Processing Record 19 of Set 6 | provost
# Processing Record 20 of Set 6 | malanje
# Processing Record 21 of Set 6 | iguape
# Processing Record 22 of Set 6 | sorgun
# Processing Record 23 of Set 6 | matane
# Processing Record 24 of Set 6 | kudat
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | pangody
# Processing Record 27 of Set 6 | beruwala
# Processing Record 28 of Set 6 | asfi
# Processing Record 29 of Set 6 | aripuana
# Processing Record 30 of Set 6 | hambantota
# Processing Record 31 of Set 6 | araxa
# Processing Record 32 of Set 6 | leningradskiy
# Processing Record 33 of Set 6 | atamanovka
# Processing Record 34 of Set 6 | san quintin
# Processing Record 35 of Set 6 | utiroa
# Processing Record 36 of Set 6 | nelson bay
# Processing Record 37 of Set 6 | santiago del estero
# Processing Record 38 of Set 6 | kadnikov
# Processing Record 39 of Set 6 | yantzaza
# Processing Record 40 of Set 6 | erzin
# Processing Record 41 of Set 6 | luderitz
# Processing Record 42 of Set 6 | jackson
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | puerto ayacucho
# Processing Record 45 of Set 6 | grand gaube
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | samusu
# Processing Record 48 of Set 6 | north bend
# Processing Record 49 of Set 6 | udhampur
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | ussel
# Processing Record 2 of Set 7 | sinnamary
# Processing Record 3 of Set 7 | sola
# Processing Record 4 of Set 7 | sorong
# Processing Record 5 of Set 7 | popondetta
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | minab
# Processing Record 8 of Set 7 | huarmey
# Processing Record 9 of Set 7 | elizabeth city
# Processing Record 10 of Set 7 | port-gentil
# Processing Record 11 of Set 7 | mys shmidta
# Processing Record 12 of Set 7 | jalu
# Processing Record 13 of Set 7 | karoi
# Processing Record 14 of Set 7 | komsomolskiy
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | norman wells
# Processing Record 17 of Set 7 | saint-joseph
# Processing Record 18 of Set 7 | abiy adi
# Processing Record 19 of Set 7 | krasavino
# Processing Record 20 of Set 7 | ngukurr
# Processing Record 21 of Set 7 | singkang
# Processing Record 22 of Set 7 | hofn
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | shaowu
# Processing Record 25 of Set 7 | sambava
# Processing Record 26 of Set 7 | ahmadpur
# Processing Record 27 of Set 7 | naze
# Processing Record 28 of Set 7 | bandar-e torkaman
# Processing Record 29 of Set 7 | saint cloud
# Processing Record 30 of Set 7 | iqaluit
# Processing Record 31 of Set 7 | narsaq
# Processing Record 32 of Set 7 | sao bento
# Processing Record 33 of Set 7 | nguiu
# Processing Record 34 of Set 7 | resistencia
# Processing Record 35 of Set 7 | kodiak
# Processing Record 36 of Set 7 | encarnacion
# Processing Record 37 of Set 7 | pemangkat
# Processing Record 38 of Set 7 | barra dos coqueiros
# Processing Record 39 of Set 7 | micheweni
# Processing Record 40 of Set 7 | tiksi
# Processing Record 41 of Set 7 | platteville
# Processing Record 42 of Set 7 | lodja
# Processing Record 43 of Set 7 | bagdarin
# Processing Record 44 of Set 7 | kaitong
# Processing Record 45 of Set 7 | puerto baquerizo moreno
# Processing Record 46 of Set 7 | tuktoyaktuk
# Processing Record 47 of Set 7 | okhotsk
# Processing Record 48 of Set 7 | antalaha
# Processing Record 49 of Set 7 | mackenzie
# Processing Record 50 of Set 7 | kruisfontein
# Processing Record 1 of Set 8 | coihaique
# Processing Record 2 of Set 8 | palabuhanratu
# Processing Record 3 of Set 8 | palmer
# Processing Record 4 of Set 8 | camacha
# Processing Record 5 of Set 8 | klaksvik
# Processing Record 6 of Set 8 | safwah
# Processing Record 7 of Set 8 | aklavik
# Processing Record 8 of Set 8 | sitka
# Processing Record 9 of Set 8 | suez
# Processing Record 10 of Set 8 | nizhneyansk
# Processing Record 11 of Set 8 | calabozo
# Processing Record 12 of Set 8 | maldonado
# Processing Record 13 of Set 8 | halifax
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | paris
# Processing Record 16 of Set 8 | maragogi
# Processing Record 17 of Set 8 | east grinstead
# Processing Record 18 of Set 8 | muros
# Processing Record 19 of Set 8 | ningan
# Processing Record 20 of Set 8 | high level
# Processing Record 21 of Set 8 | olga
# Processing Record 22 of Set 8 | cosamaloapan
# Processing Record 23 of Set 8 | hot springs
# Processing Record 24 of Set 8 | palana
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | skagastrond
# Processing Record 27 of Set 8 | le vauclin
# Processing Record 28 of Set 8 | santa ana
# Processing Record 29 of Set 8 | bandarbeyla
# Processing Record 30 of Set 8 | saleaula
# Processing Record 31 of Set 8 | ribeira grande
# Processing Record 32 of Set 8 | boende
# Processing Record 33 of Set 8 | igarka
# Processing Record 34 of Set 8 | rawlins
# Processing Record 35 of Set 8 | mutata
# Processing Record 36 of Set 8 | louisbourg
# Processing Record 37 of Set 8 | wattegama
# Processing Record 38 of Set 8 | prince george
# Processing Record 39 of Set 8 | aykhal
# Processing Record 40 of Set 8 | trinidad
# Processing Record 41 of Set 8 | west plains
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | rovaniemi
# Processing Record 44 of Set 8 | chinhoyi
# Processing Record 45 of Set 8 | formosa do rio preto
# Processing Record 46 of Set 8 | mogadishu
# Processing Record 47 of Set 8 | maues
# Processing Record 48 of Set 8 | saint-pierre
# Processing Record 49 of Set 8 | amderma
# Processing Record 50 of Set 8 | nova olimpia
# Processing Record 1 of Set 9 | kaduna
# Processing Record 2 of Set 9 | tshikapa
# Processing Record 3 of Set 9 | madang
# Processing Record 4 of Set 9 | kavaratti
# Processing Record 5 of Set 9 | yozgat
# Processing Record 6 of Set 9 | nchelenge
# Processing Record 7 of Set 9 | monroe
# Processing Record 8 of Set 9 | saskylakh
# Processing Record 9 of Set 9 | guiren
# Processing Record 10 of Set 9 | poya
# Processing Record 11 of Set 9 | tororo
# Processing Record 12 of Set 9 | bongandanga
# Processing Record 13 of Set 9 | saint anthony
# Processing Record 14 of Set 9 | koungheul
# Processing Record 15 of Set 9 | talaya
# Processing Record 16 of Set 9 | sur
# Processing Record 17 of Set 9 | constitucion
# Processing Record 18 of Set 9 | cherskiy
# Processing Record 19 of Set 9 | gornopravdinsk
# Processing Record 20 of Set 9 | gamba
# Processing Record 21 of Set 9 | ixtapa
# Processing Record 22 of Set 9 | baj
# Processing Record 23 of Set 9 | victoria point
# Processing Record 24 of Set 9 | nivala
# Processing Record 25 of Set 9 | ewa beach
# Processing Record 26 of Set 9 | beyneu
# Processing Record 27 of Set 9 | mangrol
# Processing Record 28 of Set 9 | namtsy
# Processing Record 29 of Set 9 | barreirinha
# Processing Record 30 of Set 9 | baculin
# Processing Record 31 of Set 9 | apatity
# Processing Record 32 of Set 9 | mgandu
# Processing Record 33 of Set 9 | krasnyy chikoy
# Processing Record 34 of Set 9 | taoudenni
# Processing Record 35 of Set 9 | harindanga
# Processing Record 36 of Set 9 | kyshtovka
# Processing Record 37 of Set 9 | burns lake
# Processing Record 38 of Set 9 | jiuquan
# Processing Record 39 of Set 9 | atlantis
# Processing Record 40 of Set 9 | talcahuano
# Processing Record 41 of Set 9 | limon
# Processing Record 42 of Set 9 | lalibela
# Processing Record 43 of Set 9 | plettenberg bay
# Processing Record 44 of Set 9 | wana
# Processing Record 45 of Set 9 | xunchang
# Processing Record 46 of Set 9 | tumannyy
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | port macquarie
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | zhigansk

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
